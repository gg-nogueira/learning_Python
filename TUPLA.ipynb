# %%
#Tupla é como uma lista, mas não pode ser alterada. Funções como append e pop não funcionam

# %%
num = list()
type(num)
# Out:
# list

# %%
lista = []
type(lista)
# Out:
# list

# %%
listao = [1,2,3,4]
type(listao)
# Out:
# list

# %%
tup = tuple()
type(tup)
# Out:
# tuple

# %%
tupla = ()
type(tupla)
# Out:
# tuple

# %%
tuplao = (3,)
type(tuplao)
# Out:
# tuple
