# %%
import random
import sys
from time import sleep

lista = []
password = 12345
chute=3
while chute!=0:
  try:
    #verificação de acesso
    r=str(input('Seja bem-vindo! Este app só pode ser usado por administradores!\n\nVocê é um administrador? (Responder "S" ou "N"): '))
    resp = r.upper
    while chute!=0:
      if resp=='S':
        tent=int(input('Por favor, digite sua senha: '))
        if tent==password:
          print('Acesso liberado! Aguarde um momento')
          sleep(2)
          print('............')
          sleep(2)

          x=int(input("1- Emitir Senhas\n2- Mostrar senhas\n3- Chamar senha\n4- Sair\nDigite sua opção:\n"))
          if x==1:
            while len(lista)<888:
              n=random.randint(100,999)
              if n not in lista:
                lista.append(n)
                break
                print(f'Fila: {lista}')
              elif x==2:
                print(f'Fila: {lista}')
              elif x==3:
                print(f'Senha chamada: {lista[0]}')
                lista.pop(0)
                print(f'Fila atualizada: {lista}')  
              elif x==4:
                print("Obrigado por participar!")
                break
              else:
                print('Digite apenas números válidos')
          else:
            print(f'Senha incorreta! Você tem mais {chute-1} tentativas ...')
            chute = chute-1

      elif r=='N':
        print("Sinto muito, você não pode utilizar este app.\n\n")
        chute = chute-3
        break
        

      else:
        print("Resposta inválida. Digite novamente.\n\n")
        break



  except ValueError:
    print('Digite somente números!')
  except IndexError:
    print('Primeiro armazene números na fila!')
  except KeyboardInterrupt:
    print("Obrigado por participar!")
    break;
# Out:
# Acesso liberado! Aguarde um momento
# ............
# 1- Emitir Senhas
# 2- Mostrar senhas
# 3- Chamar senha
# 4- Sair
# Digite sua opção:
# 4
# Senha incorreta! Você tem mais 2 tentativas ...
# Obrigado por participar!

# %%
import random

lista = []
while True:
  try:
    x=int(input("1- Emitir Senhas\n2- Mostrar senhas\n3- Chamar senha\n4- Sair\nDigite sua opção:\n"))
    if x==1:
      while len(lista)<888:
        n=random.randint(100,999)
        if n not in lista:
          lista.append(n)
          print(f'Fila: {lista}')
          break          
    elif x==2:
      print(f'Fila: {lista}')
    elif x==3:
      print(f'Senha chamada: {lista[0]}')
      lista.pop(0)
      print(f'Fila atualizada: {lista}')  
    elif x==4:
      print("Obrigado por participar!")
      break
    else:
      print('Digite apenas números válidos')

  except ValueError:
    print('Digite somente números!')
  except IndexError:
    print('Primeiro armazene números na fila!')
  except KeyboardInterrupt:
    print("Obrigado por participar!")
break;
# Out:
# 1- Emitir Senhas
# 2- Mostrar senhas
# 3- Chamar senha
# 4- Sair
# Digite sua opção:
# 1
# 1- Emitir Senhas
# 2- Mostrar senhas
# 3- Chamar senha
# 4- Sair
# Digite sua opção:
# 2
# Fila: [286]
# 1- Emitir Senhas
# 2- Mostrar senhas
# 3- Chamar senha
# 4- Sair
# Digite sua opção:
# 1
# 1- Emitir Senhas
# 2- Mostrar senhas
# 3- Chamar senha
# 4- Sair
# Digite sua opção:
# 1
# 1- Emitir Senhas
# 2- Mostrar senhas
# 3- Chamar senha
# 4- Sair
# Digite sua opção:
# 2
# Fila: [286, 839, 917]
# 1- Emitir Senhas
# 2- Mostrar senhas
# 3- Chamar senha
# 4- Sair
# Digite sua opção:
# 3
# Senha chamada: 286
# Fila atualizada: [839, 917]
# 1- Emitir Senhas
# 2- Mostrar senhas
# 3- Chamar senha
# 4- Sair
# Digite sua opção:
# 3
# Senha chamada: 839
# Fila atualizada: [917]
# 1- Emitir Senhas
# 2- Mostrar senhas
# 3- Chamar senha
# 4- Sair
# Digite sua opção:
# 3
# Senha chamada: 917
# Fila atualizada: []
# 1- Emitir Senhas
# 2- Mostrar senhas
# 3- Chamar senha
# 4- Sair
# Digite sua opção:
# 3
# ...

# %%
3
import random

lista = []

def intro():
  print('Seja bem-vindo!!\n\n')
  a=int(input('APENAS PARA ADMINISTRADORES!!\n\nQual o valor da 1° senha?: '))
  b=int(input('E qual é o valor da última senha?: '))
  return [a,b]

def gerar(range):
  while len(lista)<b-a:
    n=random.randint(a,b)
    if n not in lista:
      lista.append(n)
    break
  print(lista)

def mostra():
  print(lista)

def tira():
  print(f'Senha chamada: {lista[0]}')
  lista.pop(0)
  print(f'Fila atualizada: {lista}') 

def menu():
  try:
    while True:
      x= int(input("1- Emitir Senhas\n2- Mostrar senhas\n3- Chamar senha\n4- Sair\nDigite sua opção:\n"))
      if x==1:
        gerar()
      elif x==2:
        mostra()
      elif x==3:
        tira()
      elif x==4:
        print("Obrigado por participar!")
        break
      else:
        print('Digite apenas números válidos')

  except ValueError:
    print('Digite somente números!')
    menu()
  except IndexError:
    print('Primeiro armazene números na fila!')
    menu()
  except KeyboardInterrupt:
    print("Obrigado por participar!")

def main():
  range = intro()
  menu(intro)

# %%
main()
# Out:
# Seja bem-vindo!!
#
#
# APENAS PARA ADMINISTRADORES!!
#
# Qual o valor da 1° senha?: 1
# E qual é o valor da última senha?: 10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-263240bbee7e> in <module>
# ----> 1 main()
#
# <ipython-input-9-42338519f59d> in main()
#      52 def main():
#      53   intro()
# ---> 54   menu(intro)
#
# TypeError: menu() takes 0 positional arguments but 1 was given

# %%
import pandas as pd
import numpy as np
  
df = pd.read_excel("sample.xlsx")
print(df)
# Out:
#    nome  idade
# 0    n1     10
# 1    n2     11
# 2    n3     12
# 3    n4     13
# 4    n5     14
# 5    n6     15
# 6    n7     16
# 7    n8     17
# 8    n9     18
# 9   n10     19
# 10  n11     20
# 11  n12     21

# %%
df["idade"].mean()
# Out:
# 15.5
