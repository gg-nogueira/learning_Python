# %%
lista = [1,2,3,4,5]
lista
# Out:
# [1, 2, 3, 4, 5]

# %%
lista[2]
# Out:
# 3

# %%
lista [2] = 100
lista
# Out:
# [1, 2, 100, 4, 5]

# %%
lista.insert(3,10)
lista
# Out:
# [1, 2, 100, 10, 10, 10, 10, 5, 50]

# %%
del lista[4]
lista
# Out:
# [1, 2, 100, 10, 5]

# %%
lista.append(5015)
lista
# Out:
# [1, 2, 100, 10, 10, 10, 10, 5, 50, 50, 5015]

# %%
y = lista.pop(2)
print(lista)
print(y)
# Out:
# [1, 2, 10, 10, 10, 10, 5, 50, 50, 5015]
# 100

# %%
listao = []

for i in range(4):
  listao.append(int(input(f'poe o n° {i+1}: ')))

listao
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-cdc3d34a267e> in <cell line: 3>()
#       2
#       3 for i in range(4):
# ----> 4   listao.append(int(input(f'poe o n° {i+1}: ')))
#       5
#       6 listao
#
# /usr/local/lib/python3.9/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.9/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
listao2 = list(range(2,10,2))
listao2

# %%
meu_dicio = [{'Nome': 'Gabs', 'Tel': [12345678, 562673734]}, {'Nome': 'Gui', 'Tel': 11969426971}]

meu_dicio[0]['Apelido'] = meu_dicio[0].pop('Nome')
meu_dicio[0]['Tel'][0] = 987654312
meu_dicio

# %%
while True:

  try:
    x=int(input("bota um numero ae: "))
    y=int(input("bota outro numero ae: "))

    print(f'A soma é {x}{y}')
    break

  except ValueError:
    print('N Ú M E R O SEU IMBECIL')
    break
  except KeyboardInterrupt:
    print('Parou? Ta com medinha?')
    break
    exit()
