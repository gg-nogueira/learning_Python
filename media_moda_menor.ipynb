# %%
import random

x=[]
cont=0
acum=0

for i in range (5):
  x.append(random.randint(1,9))
  cont += 1
  acum += x[i]

print(x)





print(f'A média é: {acum/cont}')
print(f)
# Out:
# [6]
# [6, 3]
# [6, 3, 8]
# [6, 3, 8, 2]
# [6, 3, 8, 2, 1]
# A média é: 4.0

# %%
x
# Out:
# 8
