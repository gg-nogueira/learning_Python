# %%
#sintaxe: {chave : valor}

cadastro = [{'cliente':'Marcos', 'idade': 18, 'profissao': 'DBA'}, {'cliente':'Gerson', 'idade': 38, 'profissao': 'DEV'}, {'cliente':'Macaco', 'idade': 7, 'profissao': 'Professor'} ]


cadastro[0]['cliente']
# Out:
# 'Marcos'

# %%
dicio=dict()

dicio['nome']='josefo'
dicio['idade']=18
dicio['rua']='catorze'
dicio['serie']='2A'

# %%
cadastro.append({'cliente':'jessica'})
cadastro[3]
# Out:
# {'cliente': 'jessica'}

# %%
cadastro[3]['idade']=23
cadastro
# Out:
# [{'cliente': 'Marcos', 'idade': 18, 'profissao': 'DBA'},
#  {'cliente': 'Gerson', 'idade': 38, 'profissao': 'DEV'},
#  {'cliente': 'Macaco', 'idade': 7, 'profissao': 'Professor'},
#  {'cliente': 'jessica', 'idade': 23}]

# %%
cadastro[3].pop('idade')
cadastro
# Out:
# [{'cliente': 'Marcos', 'idade': 18, 'profissao': 'DBA'},
#  {'cliente': 'Gerson', 'idade': 38, 'profissao': 'DEV'},
#  {'cliente': 'Macaco', 'idade': 7, 'profissao': 'Professor'},
#  {'cliente': 'jessica'}]

# %%
cadastro[0].keys()
# Out:
# dict_keys(['cliente', 'idade', 'profissao'])

# %%
for x,y in dicio.items():
  print(f'{x} = {y}')
# Out:
# nome = josefo
# idade = 18
# rua = catorze
# serie = 2A

# %%
dicio
# Out:
# {'nome': 'josefo', 'idade': 18, 'rua': 'catorze', 'serie': '2A'}

# %%
dicio.items()
# Out:
# dict_items([('nome', 'josefo'), ('idade', 18), ('rua', 'catorze'), ('serie', '2A')])

# %%
dados = {}

dados['nome']= str(input("Nome: "))
dados['idade']= int(input("Idade: "))
dados['salario']= float(input("Salário: "))

print()

for k,v in dados.items():
  print(f'{')
# Out:
#   File "<ipython-input-10-7e159a4d27d9>", line 10
#     print(f'{')
#               ^
# SyntaxError: f-string: expecting '}'
